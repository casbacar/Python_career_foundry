# %%
import pandas as pd
import numpy as np
import os

# %%
#Importing the file

df_1 = pd.read_pickle(r'C:\Users\casbacar\Documents\Study\Data Immersion\Achievement 4\03_2025_Instacart basked analysis\03 Scripts\Prepared data\ ords_prods_merge.pkl')

# %% [markdown]
# # Exercise 4.7

# %%
# I modify the loop used previously to include second busiest and slowest day

result = []

for value in df_1["order_dow"]:
  if value in [0,1]:
    result.append("Busiest days")
  elif value in [3,4]:
    result.append("Least busy days")
  else:
    result.append("Regularly busy")

# %%
# Create a new column with all the new values
df_1['Busiest days'] = result

# %%
#Checking values of the Busiest days column have been updated

df_1.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   3139998      138    prior            28          6                 11
# 1   1977647      138    prior            30          6                 17
# 2    389851      709    prior             2          0                 21
# 3    652770      764    prior             1          3                 13
# 4   1813452      764    prior             3          4                 17
#
#    days_since_prior_order  add_to_cart_order  reordered _merge  \
# ...

# %%
# Step 4 - Checking the hours with the most orders

df_1['order_hour_of_day'].value_counts(dropna = False)
# Out:
# order_hour_of_day
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: count, dtype: int64

# %%
# Checking the average hour with the average horders

df_1['order_hour_of_day'].mean()
# Out:
# 13.42514895682774

# %%
# Create loop for orders frequency per hours

result_hour_of_day = []

for value in df_1["order_hour_of_day"]:
  if value > 13:
    result_hour_of_day.append("Most orders")
  elif value == 13:
    result_hour_of_day.append("Average orders")
  else:
    result_hour_of_day.append("Fewer orders")

# %%
# We add the new column to our dataframe

df_1['Busiest hours'] = result_hour_of_day

# %%
# Now we confirm the new columnt has been created successfully

df_1
# Out:
#           product_id                product_name  aisle_id  department_id  \
# 0                  1  Chocolate Sandwich Cookies        61             19
# 1                  1  Chocolate Sandwich Cookies        61             19
# 2                  1  Chocolate Sandwich Cookies        61             19
# 3                  1  Chocolate Sandwich Cookies        61             19
# 4                  1  Chocolate Sandwich Cookies        61             19
# ...              ...                         ...       ...            ...
# 32404854       49688      Fresh Foaming Cleanser        73             11
# 32404855       49688      Fresh Foaming Cleanser        73             11
# 32404856       49688      Fresh Foaming Cleanser        73             11
# 32404857       49688      Fresh Foaming Cleanser        73             11
# 32404858       49688      Fresh Foaming Cleanser        73             11
#
#           prices  order_id  user_id eval_set  order_number  order_dow  \
# ...

# %%
# Step 6 - We print the frequency of this column

df['Busiest hours'].value_counts(dropna = False)
# Out:
# Busiest hours
# Most orders       15677277
# Fewer orders      14066628
# Average orders     2660954
# Name: count, dtype: int64

# %%
# Exporting to pkl file

df_1.to_pickle('C:\\Users\\casbacar\\Documents\\Study\\Data Immersion\\Achievement 4\\03_2025_Instacart basked analysis\\03 Scripts\\Prepared Data\\ ords_hour_day_busy_4.7.pkl')
